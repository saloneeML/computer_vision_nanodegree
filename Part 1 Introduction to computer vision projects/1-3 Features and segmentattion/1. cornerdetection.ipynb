# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#Read in the image
image = cv2.imread('images/waffle.jpg')
#Make a copy of the image
image_copy = np.copy(image)
#Change the color to RGB
image_copy = cv2.cvtColor(image_copy,cv2.COLOR_BGR2RGB)
#Display the image
plt.imshow(image_copy)

# %%
#Convert the image to grayscale
gray = cv2.cvtColor(image_copy,cv2.COLOR_RGB2GRAY)
gray = np.float32(gray)
#Display the grayscale image
plt.imshow(gray,cmap='gray')

# %%
#Detect cornerharris detector
dst = cv2.cornerHarris(gray,2,3,0.04)
plt.imshow(dst,cmap='gray')

# %%
#Dilate corner image to enhance corner points
dst = cv2.dilate(dst,None)
plt.imshow(dst,cmap='gray')

# %%
#Define threshold for extracting strong corner points
thresh = 0.01 * dst.max()

# %%
#Create an image copy to draw corners on
corner_image = np.copy(image_copy)

# %%
#Iterate through all corners and draw them on the image
for j in range(0,dst.shape[0]):
    for i in range(0,dst.shape[1]):
        if(dst[j,i] > thresh):
            #image,center point,radius,color,thickness
            cv2.circle(corner_image,(i,j),1,(0,255,0),1)
plt.imshow(corner_image)
